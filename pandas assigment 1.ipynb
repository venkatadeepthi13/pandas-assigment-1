# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\DELL\Downloads\cleaned_all_phones.csv")

# %%
data
# Out:
#             phone_name   brand           os  inches resolution  battery  \
# 0         Y6II Compact  Huawei  Android 5.1    5.00   720x1280     2200
# 1             K20 plus      LG  Android 7.0    5.30   720x1280     2700
# 2       P8 Lite (2017)  Huawei  Android 7.0    5.20  1080x1920     3000
# 3         Redmi Note 4  Xiaomi  Android 6.0    5.50  1080x1920     4100
# 4                  P10  Huawei  Android 7.0    5.10  1080x1920     3200
# ...                ...     ...          ...     ...        ...      ...
# 1507         vivo Y77t    Vivo   Android 13    6.64  1080x2388     5000
# 1508               11x  Realme   Android 13    6.72  1080x2400     5000
# 1509               GT5  Realme   Android 13    6.74  1240x2772     5240
# 1510          GT5 240W  Realme   Android 13    6.74  1240x2772     4600
# 1511  vivo iQOO Z7 Pro    Vivo   Android 13    6.78  1080x2400     4600
#
#      battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# ...

# %%
data.head()
# Out:
#        phone_name   brand           os  inches resolution  battery  \
# 0    Y6II Compact  Huawei  Android 5.1     5.0   720x1280     2200
# 1        K20 plus      LG  Android 7.0     5.3   720x1280     2700
# 2  P8 Lite (2017)  Huawei  Android 7.0     5.2  1080x1920     3000
# 3    Redmi Note 4  Xiaomi  Android 6.0     5.5  1080x1920     4100
# 4             P10  Huawei  Android 7.0     5.1  1080x1920     3200
#
#   battery_type  ram(GB) announcement_date  weight(g)  ...  video_1080p  \
# 0        Li-Po        2        2016-09-01      140.0  ...        False
# 1       Li-Ion        2        2016-12-01      140.0  ...         True
# 2       Li-Ion        4        2017-01-01      147.0  ...         True
# 3        Li-Po        4        2017-01-01      165.0  ...         True
# 4       Li-Ion        4        2017-02-01      145.0  ...         True
#
#    video_4K  video_8K  video_30fps  video_60fps  video_120fps  video_240fps  \
# ...

# %%
#How many unique  mobile brands are there in the data provided

# %%
data["brand"].unique().shape
# Out:
# (13,)

# %%
# 13 unique  mobile brands are there in the data provided

# %%
#What is the average ram size of all the collected data

# %%
data["ram(GB)"].mean()
# Out:
# 6.6838624338624335

# %%
#6.6838624338624335 is the average ram size of all the collected data

# %%
#Which phone is having the maximum and minimum battery capacity

# %%
data["phone_name"][(data["battery"]==data["battery"].max())]
# Out:
# 573    V6
# Name: phone_name, dtype: object

# %%
data["phone_name"][(data["battery"]==data["battery"].min())]
# Out:
# 62             iPhone 8
# 536    iPhone SE (2020)
# Name: phone_name, dtype: object

# %%
#V6 phone is having the maximum battery capacity 
# iphone8 and iphone SE phones having minimum battery capacity

# %%
#What is the maximum battery capacity provided by Huawei Company

# %%
data["battery"][(data["brand"]=="Huawei")].max()
# Out:
# 7000

# %%
#7000 is the maximum battery capacity provided by Huawei Company

# %%
#Which Phone brand is providing the highest and lowest ram

# %%
data["brand"][(data["ram(GB)"]==data["ram(GB)"].max())].unique()
# Out:
# array(['Xiaomi', 'OnePlus', 'Realme'], dtype=object)

# %%
data["brand"][(data["ram(GB)"]==data["ram(GB)"].min())].unique()
# Out:
# array(['Huawei', 'Samsung', 'Xiaomi', 'LG'], dtype=object)

# %%
#Xiaomi,OnePlus,Realme are the Phone brand is providing the highest ram
#Huawei,Samsung,Xiaomi are the Phone brand is providing the low ram

# %%
data.columns
# Out:
# Index(['phone_name', 'brand', 'os', 'inches', 'resolution', 'battery',
#        'battery_type', 'ram(GB)', 'announcement_date', 'weight(g)',
#        'storage(GB)', 'video_720p', 'video_1080p', 'video_4K', 'video_8K',
#        'video_30fps', 'video_60fps', 'video_120fps', 'video_240fps',
#        'video_480fps', 'video_960fps', 'price(USD)'],
#       dtype='object')

# %%
#How many phones has android 7.0 as there operating system

# %%
data["phone_name"][(data["os"]=="Android 7.0")].count()
# Out:
# 33

# %%
#33 phones has android 7.0 as there operating system

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   object
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
#Which Phone is the oldest

# %%
data["announcement_date"]=pd.to_datetime(data["announcement_date"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1512 entries, 0 to 1511
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   phone_name         1512 non-null   object
#  1   brand              1512 non-null   object
#  2   os                 1512 non-null   object
#  3   inches             1512 non-null   float64
#  4   resolution         1512 non-null   object
#  5   battery            1512 non-null   int64
#  6   battery_type       1512 non-null   object
#  7   ram(GB)            1512 non-null   int64
#  8   announcement_date  1512 non-null   datetime64[ns]
#  9   weight(g)          1512 non-null   float64
#  10  storage(GB)        1512 non-null   int64
#  11  video_720p         1512 non-null   bool
#  12  video_1080p        1512 non-null   bool
#  13  video_4K           1512 non-null   bool
#  14  video_8K           1512 non-null   bool
#  15  video_30fps        1512 non-null   bool
# ...

# %%
data2=pd.pivot_table(data,index="phone_name",columns="brand",values="price(USD)",aggfunc=["count"],margins=True)

# %%
data2
# Out:
#                  count                                                   \
# brand            Apple Google  Honor Huawei    LG Lenovo OnePlus   Oppo
# phone_name
# 1                  NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10                 NaN    NaN    1.0    NaN   NaN    NaN     NaN    NaN
# 10 5G              NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10 Lite            NaN    NaN    1.0    NaN   NaN    NaN     NaN    NaN
# 10 Pro             NaN    NaN    NaN    NaN   NaN    NaN     1.0    NaN
# ...                ...    ...    ...    ...   ...    ...     ...    ...
# vivo iQOO Z7 Pro   NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7i      NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7s      NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7x      NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# All               22.0   19.0  124.0  137.0  75.0   43.0    47.0  213.0
#
#
# ...

# %%
#Which brand produced maximum number of phone in the given data

# %%
data2=pd.pivot_table(data,index="phone_name",columns="brand",values="price(USD)",aggfunc=["max"],margins=True)

# %%
data2
# Out:
#                       max                                                  \
# brand               Apple  Google   Honor  Huawei      LG Lenovo  OnePlus
# phone_name
# 1                     NaN     NaN     NaN     NaN     NaN    NaN      NaN
# 10                    NaN     NaN   310.0     NaN     NaN    NaN      NaN
# 10 5G                 NaN     NaN     NaN     NaN     NaN    NaN      NaN
# 10 Lite               NaN     NaN   180.0     NaN     NaN    NaN      NaN
# 10 Pro                NaN     NaN     NaN     NaN     NaN    NaN   439.94
# ...                   ...     ...     ...     ...     ...    ...      ...
# vivo iQOO Z7 Pro      NaN     NaN     NaN     NaN     NaN    NaN      NaN
# vivo iQOO Z7i         NaN     NaN     NaN     NaN     NaN    NaN      NaN
# vivo iQOO Z7s         NaN     NaN     NaN     NaN     NaN    NaN      NaN
# vivo iQOO Z7x         NaN     NaN     NaN     NaN     NaN    NaN      NaN
# ...

# %%
data["brand"][data["price(USD)"]==2300]
# Out:
# 777    Huawei
# Name: brand, dtype: object

# %%
#Huawei brand produced maximum number of phone in the given data

# %%
data2=pd.pivot_table(data,index="phone_name",columns="brand",values="price(USD)",aggfunc=["min"],margins=True)

# %%
data2
# Out:
#                     min                                                   \
# brand             Apple Google  Honor Huawei    LG Lenovo OnePlus   Oppo
# phone_name
# 1                   NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10                  NaN    NaN  310.0    NaN   NaN    NaN     NaN    NaN
# 10 5G               NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10 Lite             NaN    NaN  180.0    NaN   NaN    NaN     NaN    NaN
# 10 Pro              NaN    NaN    NaN    NaN   NaN    NaN  439.94    NaN
# ...                 ...    ...    ...    ...   ...    ...     ...    ...
# vivo iQOO Z7 Pro    NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7i       NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7s       NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7x       NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# All               189.5  238.0   90.0   90.0  70.0   90.0  119.00  100.0
#
#
# ...

# %%
data["phone_name"][data["price(USD)"]==40]
# Out:
# 452    C2s
# Name: phone_name, dtype: object

# %%
#C2s brand produced maximum number of phone in the given data

# %%
#Give the count of phones supporting
#4k video
#8k video
#2k video

# %%
data2
# Out:
#                     count                                                   \
#                  video_4K
# brand               Apple Google  Honor Huawei    LG Lenovo OnePlus   Oppo
# phone_name
# 1                     NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10                    NaN    NaN    1.0    NaN   NaN    NaN     NaN    NaN
# 10 5G                 NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10 Lite               NaN    NaN    1.0    NaN   NaN    NaN     NaN    NaN
# 10 Pro                NaN    NaN    NaN    NaN   NaN    NaN     1.0    NaN
# ...                   ...    ...    ...    ...   ...    ...     ...    ...
# vivo iQOO Z7 Pro      NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7i         NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7s         NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7x         NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# ...

# %%
data2=pd.pivot_table(data,index="phone_name",columns="brand",values=["video_8K"],aggfunc=["count"],margins=True)

# %%
data2
# Out:
#                     count                                                   \
#                  video_8K
# brand               Apple Google  Honor Huawei    LG Lenovo OnePlus   Oppo
# phone_name
# 1                     NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10                    NaN    NaN    1.0    NaN   NaN    NaN     NaN    NaN
# 10 5G                 NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# 10 Lite               NaN    NaN    1.0    NaN   NaN    NaN     NaN    NaN
# 10 Pro                NaN    NaN    NaN    NaN   NaN    NaN     1.0    NaN
# ...                   ...    ...    ...    ...   ...    ...     ...    ...
# vivo iQOO Z7 Pro      NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7i         NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7s         NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# vivo iQOO Z7x         NaN    NaN    NaN    NaN   NaN    NaN     NaN    NaN
# ...

# %%
data["brand"][data["video_4K"]].count()
# Out:
# 801

# %%
data["brand"][data["video_8K"]].count()
# Out:
# 86

# %%
data["brand"][data["video_1080p"]].count()
# Out:
# 1503

# %%
#801 of phones supporting 4k video
#86 of phones supporting 8k video
#1503 of phones supporting 1080 video

# %%
data["phone_name"][(data["announcement_date"]==min(data["announcement_date"]))]
print(min(data["announcement_date"]))
# Out:
# 2016-09-01 00:00:00

# %%
#How many phones supports Li-Po and Li-ion Battery

# %%
data['phone_name'][(data['battery_type']=='Li-Po') & (data['battery_type']=='Li-ion')].count()
# Out:
# 0

# %%
#How many sony phones supports 720x1280 resolution

# %%
data['phone_name'][(data['resolution']=='720x1280') & (data['phone_name']=='sony')]
# Out:
# Series([], Name: phone_name, dtype: object)
